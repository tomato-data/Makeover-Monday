# %%
import pandas as pd

df = pd.read_csv('Global Population 2023.csv', index_col=0)

# %%
def clean_density(value):
    if pd.isna(value):
        return np.nan
    elif isinstance(value, str):
        return int(value.replace(',', ''))
    else:
        return int(value)

def clean_urpop(value):
    if value[-1] == '%':
        return int(value.replace(' %', ''))
    elif value == 'N.A.':
        return np.nan
    else:
        return value

df['Population\n(2023)'] = df['Population\n(2023)'].apply(clean_density)
df['Density\n(P/Km²)'] = df['Density\n(P/Km²)'].apply(clean_density)
df['Urban\nPop %'] = df['Urban\nPop %'].apply(clean_urpop)
df
# Out:
#     Country (or dependency)  Population\n(2023) Yearly\nChange  Net\nChange  \
# #
# 1                     India          1428627663         0.81 %     11454490
# 2                     China          1425671352        -0.02 %      -215985
# 3             United States           339996563         0.50 %      1706706
# 4                 Indonesia           277534122         0.74 %      2032783
# 5                  Pakistan           240485658         1.98 %      4660796
# ..                      ...                 ...            ...          ...
# 230              Montserrat                4386        -0.09 %           -4
# 231        Falkland Islands                3791         0.29 %           11
# 232                    Niue                1935         0.05 %            1
# 233                 Tokelau                1893         1.18 %           22
# 234                Holy See                 518         1.57 %            8
#
# ...

# %%
import plotly.graph_objs as go
import numpy as np 
import statsmodels.api as sm

lowess_fit = sm.nonparametric.lowess(df_clean['Med.\nAge'], df_clean['Fert.\nRate'])

fig = go.Figure()
fig.add_trace(go.Scatter(
    name = 'Country',
    x = df['Fert.\nRate'],
    y = df['Med.\nAge'],
    mode = 'markers',
    hoverinfo='text',
    hovertext=df['Country (or dependency)']
))

fig.add_trace(go.Scatter(
    mode = 'lines',
    x = lowess_fit[:,0], 
    y = lowess_fit[:,1],
    name = 'lowess'
))

fig.update_layout(
    xaxis = dict(title = 'Fertility Rate'),
    yaxis = dict(title = 'Median Age')
)

fig.show()
# Out:
# <div>                            <div id="ae67cb9b-9be7-4d35-af4b-914095f1deb3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae67cb9b-9be7-4d35-af4b-914095f1deb3")) {                    Plotly.newPlot(                        "ae67cb9b-9be7-4d35-af4b-914095f1deb3",                        [{"hoverinfo":"text","hovertext":["India","China","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico","Ethiopia","Japan","Philippines","Egypt","DR Congo","Vietnam","Iran","Turkey","Germany","Thailand","United Kingdom","Tanzania","France","South Africa","Italy","Kenya","Myanmar","Colombia","South Korea","Uganda","Sudan","Spain","Argentina","Algeria","Iraq","Afghanistan","Poland","Canada","Morocco","Saudi Arabia","Ukraine","Angol
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(
    name = 'Country',
    x = df['Urban\nPop %'],
    y = df['Density\n(P/Km²)'],
    mode = 'markers',
    hoverinfo='text',
    hovertext=df['Country (or dependency)']
))
# Out:
# <div>                            <div id="fbf8ad35-25b8-4543-b585-c4726e7fa872" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fbf8ad35-25b8-4543-b585-c4726e7fa872")) {                    Plotly.newPlot(                        "fbf8ad35-25b8-4543-b585-c4726e7fa872",                        [{"hoverinfo":"text","hovertext":["India","China","United States","Indonesia","Pakistan","Nigeria","Brazil","Bangladesh","Russia","Mexico","Ethiopia","Japan","Philippines","Egypt","DR Congo","Vietnam","Iran","Turkey","Germany","Thailand","United Kingdom","Tanzania","France","South Africa","Italy","Kenya","Myanmar","Colombia","South Korea","Uganda","Sudan","Spain","Argentina","Algeria","Iraq","Afghanistan","Poland","Canada","Morocco","Saudi Arabia","Ukraine","Angol
# ...

# %%
a = 'N.A.'
def check(value):
    if value[-1] == '%':
        return int(value.replace(' %', ''))
    else:
        return np.nan
check(a)
# Out:
# nan
